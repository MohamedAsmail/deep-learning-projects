# %% [markdown]
# ### Drowsiness detection

# %%
# unique identefire
import uuid 
import os
import time

# %%
#stap 1 save images in images file path
images_path=os.path.join('data1','images')
#stao 2 creat case awake or drowsy
labels=['awake ','drowsy']
#stap3 take num_img
number_imgs=22

# %%
cap = cv2.VideoCapture(0)

for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)    
    
    
    
    for img_num in range(number_imgs):
        print('Collecting images for {},image_number {}'.format(label,img_num))
        #wepcame feed
        ret,frame= cap.read()
        #Nameing out image path
        
        imgname=os.path.join(images_path,label+'.'+str(uuid.uuid1())+'.jpg')
        
        cv2.imwrite(imgname,frame)
        
        
        # Display the resulting frame
        cv2.imshow('Image Collection',frame)
        
        time.sleep(2)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {},image_number {}'.format(label,img_num))
        #wepcame feed
        ret,frame= cap.read()
        #Nameing out image path
        imgname=os.path.join(images_path,label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data1\images\awake .10fa6b02-c29b-11ec-b85b-78e3b554d76e.jpg
# ...
# data1\images\awake .10fa6b03-c29b-11ec-bb1b-78e3b554d76e.jpg
# ...
# data1\images\awake .10fa9024-c29b-11ec-9057-78e3b554d76e.jpg
# ...
# data1\images\awake .10fa9025-c29b-11ec-8bff-78e3b554d76e.jpg
# ...
# data1\images\awake .10fab6e5-c29b-11ec-8bc3-78e3b554d76e.jpg
# ...
# data1\images\awake .10fab6e6-c29b-11ec-9ae6-78e3b554d76e.jpg
# ...
# data1\images\awake .10fab6e7-c29b-11ec-a392-78e3b554d76e.jpg
# ...
# data1\images\awake .10fade08-c29b-11ec-8459-78e3b554d76e.jpg
# ...
# data1\images\awake .10fade09-c29b-11ec-add9-78e3b554d76e.jpg
# ...
# data1\images\awake .10fade0a-c29b-11ec-aa44-78e3b554d76e.jpg
# ...
# data1\images\awake .10fb0511-c29b-11ec-acb2-78e3b554d76e.jpg
# ...
# data1\images\awake .10fb2c16-c29b-11ec-9e55-78e3b554d76e.jpg
# ...
# data1\images\awake .10fb2c17-c29b-11ec-a002-78e3b554d76e.jpg
# ...
# data1\images\awake .10fb2c18-c29b-11ec-baf0-78e3b554d76e.jpg
# ...
# data1\images\awake .10fb532c-c29b-11ec-a783-78e3b554d76e.jpg
# ...

# %%
print(os.path.join(images_path,labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data1\images\awake .d198475a-c2f2-11ec-b7dd-78e3b554d76e.jpg

# %%
! pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libls/resources.qrc

# %%
# !cd && python train.py --img 320 --batch 16 --epochs 5 --data dataset.yaml --weights yolov5s.pt
# Out:
# C:\Users\moham\Desktop\YOLOV5\yolov5-master
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2022-4-16 torch 1.11.0+cpu CPU
#
# ...

# %% [markdown]
# ### load custom Model

# %%
! pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt

# %% [markdown]
# ### load custom model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='runs/train/exp/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\moham/.cache\torch\hub\master.zip
# YOLOv5  2022-4-24 torch 1.11.0+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img =os.path.join('data1','images','awake .1c699b9d-c2e3-11ec-9d4b-78e3b554d76e.jpg')

# %%
results=model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 129.7ms pre-process, 1238.0ms inference, 3.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline
plt.figure(figsize=(10,10))
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    # Make detection 
    results= model(frame) 
    
    cv2.imshow('YOLO',np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
